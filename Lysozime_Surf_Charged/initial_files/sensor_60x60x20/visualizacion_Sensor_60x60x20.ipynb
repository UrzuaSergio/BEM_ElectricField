# %%
import numpy
vertices=open('sensor_60x60x20_d08.vert','r')
VERT=numpy.loadtxt(vertices)
VERT_COPY=numpy.copy(VERT)

# %%
print(VERT)
# Out:
# [[ 30.         -30.         -20.        ]
#  [ 30.         -30.         -19.71428571]
#  [ 30.         -30.         -19.42857143]
#  ...,
#  [ 30.          28.28571429 -20.        ]
#  [ 30.          29.14285714 -20.        ]
#  [ 30.          30.         -20.        ]]

# %%
import matplotlib.pyplot as plt

# %%
X=VERT_COPY[:,0]
Y=VERT_COPY[:,1]
Z=VERT_COPY[:,2]

print(X, Y, Z)
# Out:
# [ 30.  30.  30. ...,  30.  30.  30.] [-30.         -30.         -30.         ...,  28.28571429  29.14285714  30.        ] [-20.         -19.71428571 -19.42857143 ..., -20.         -20.         -20.        ]

# %%
plt.plot(X,Y)
plt.show()

# %%
plt.plot(X,Z)
plt.show()
